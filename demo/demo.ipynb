# %%
from src.pipeline import PaperToProdPipeline

# %%
with open("../samples/sample_paper.txt") as f:
    paper = f.read()

# %%
pipeline = PaperToProdPipeline()
code, is_valid = pipeline.run(paper)

# %%
print("Generated Code:")
print(code)
print("Validation Passed:", is_valid)
